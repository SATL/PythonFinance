# %% [markdown]
# # Welcome to Hello World

# %% [markdown]
# Text Examples
# ===
# this is an example of *italic* text.
# This is an example of a **bold** text.
#
# This is an example of a list item:
# - Item #1
# - Item #2
# - Item #3
#
# ---
#
# # heading1
# ## heading 2
# ### heading 3
# #### heading 4
# ##### heading 5
# ###### heading 6

# %%
answer = 3+5

# %%
print(answer)
# Out:
# 8

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
x = np.linspace(0, 2*math.pi)
plt.plot(x, np.sin(x), label = r'$\sin(x)$')
plt.plot(x, np.cos(x), 'ro', label =r'$\cos(x)$')
plt.title(r'Two plots in a graph')
plt.legend()

# %%
plt.show()

# %% [markdown]
# $$N(x) = \frac{1}{\sqrt{2\pi}}\int_{-\infty}^{x} e^{- \frac{z^2}{2}}\, dz$$

# %%
from IPython.display import Math
Math(r'N(x)=\frac{1}{\sqrt{2\pi}}\int_{-\infty}^{x} e^{- \frac{z^2}{2}}\, dz')
# Out:
# $$N(x)=\frac{1}{\sqrt{2\pi}}\int_{-\infty}^{x} e^{- \frac{z^2}{2}}\, dz$$

# %% [markdown]
# This expression $\sqrt{3x-1}+(1+x)^2$ is an example of a Tex inline equation

# %%
from IPython.display import Image
Image(url='http://python.org/images/python-logo.gif')
# Out:
# <img src="http://python.org/images/python-logo.gif"/>

# %%
from IPython.lib.display import YouTubeVideo
YouTubeVideo('tKTZoB2Vjuk')

# %%
from IPython.display import HTML
table = """<table> <tr> <th>Header 1</th> <th>Header 2</th> </tr> <tr> <td>row 1, cell 1</td> <td>row 1, cell 2</td> </tr> <tr> <td>row 2, cell 1</td> <td>row 2, cell 2</td> </tr> </table>""" 
HTML(table)
# Out:
# <table> <tr> <th>Header 1</th> <th>Header 2</th> </tr> <tr> <td>row 1, cell 1</td> <td>row 1, cell 2</td> </tr> <tr> <td>row 2, cell 1</td> <td>row 2, cell 2</td> </tr> </table>

# %%
import pandas-datareader.data as web
import datetime
start = datetime.datetime(2014, 1, 1)
end = datetime.datetime(2014, 12, 32)
df = web.DataReader("AAPL", 'yahoo', start, end)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-178a7302efb8> in <module>()
# ----> 1 import pandas.io.data as web
#       2 import datetime
#       3 start = datetime.datetime(2014, 1, 1)
#       4 end = datetime.datetime(2014, 12, 32)
#       5 df = web.DataReader("AAPL", 'yahoo', start, end)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\data.py in <module>()
#       1 raise ImportError(
# ----> 2     "The pandas.io.data module is moved to a separate package "
#       3     "(pandas-datareader). After installing the pandas-datareader package "
#       4     "(https://github.com/pydata/pandas-datareader), you can change "
#       5     "the import ``from pandas.io import data, wb`` to "
#
# ImportError: The pandas.io.data module is moved to a separate package (pandas-datareader). After installing the pandas-datareader package (https://github.com/pydata/pandas-datareader), you can change the import ``from pandas.io import data, wb`` to ``from pandas_datareader import data, wb``.
